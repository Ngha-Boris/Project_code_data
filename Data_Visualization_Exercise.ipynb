# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('~/env/data.csv')  # replace 'path_to_your_data_file.csv' with your file path
data = pd.read_csv('data.csv')

print(data.head())
# Display the first few rows of the dataset
# TODO
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
##shape of the dataset
shape = data.shape
num_rows = shape[0]
num_columns = shape[1]

print("Number of row:", num_rows)
print("Number of columns:", num_columns)

#Check for missing values
missing_values = data.isnull().sum()

#counting total number of missing value
total_missing_values = missing_values.sum()

if total_missing_values > 0:
    print("There are missing values in data.csv.")
    print("Number of missing values:", total_missing_values)
    print(missing_values)
else:
    print("There are no missing values data.csv.")
# Out:
# Number of row: 6362620
# Number of columns: 11
# There are no missing values data.csv.

# %%
data['amount'].describe()
# Out:
# count    6.362620e+06
# mean     1.798619e+05
# std      6.038582e+05
# min      0.000000e+00
# 25%      1.338957e+04
# 50%      7.487194e+04
# 75%      2.087215e+05
# max      9.244552e+07
# Name: amount, dtype: float64

# %%
#counting the occurances of each transacton type
transaction_counts = data['type'].value_counts()

#bar chat plot
plt.figure(figsize=(10,4))
transaction_counts.plot(kind='bar')
plt.xlabel('Transaction type')
plt.ylabel('Count')
plt.show()

# %%
#counting the occurances of each transacton type
transaction_anmount = data['amount']

#bar chat plot
sns.histplot(transaction_amount, bins=30)
plt.xlabel('Amount')
plt.ylabel('Count')
plt.show()

# %%
#The mos

# %%
fraud_count = data['isFraud'].value_counts()
plt.pie(fraud_count, labels=fraud_count.index, autopct='%1.2f%%')
plt.title('proportion of fraudulent vs non-proportion of fraudulent')
plt.axis('equal')
plt.show()

# %%
#
old_balance = data['oldbalanceOrg']
new_balance = data['newbalanceOrig']

#ploting the scatered plot
plt.figure(figsize=(10, 6))
plt.scatter(old_balance, new_balance, alpha=0.5)
plt.xlabel('old Balance')
plt.ylabel('New Balance')
plt.title('Scatter Plot: old Balance vs. New Balance')
plt.show()

# %%
fraudulent_counts = data['isFraud'].value_counts()
fraudulent_counts.plot.bar()
plt.xlabel('isFraud')
plt.ylabel('count')
plt.title('number of transaction flagged ad fraud')
plt.show()
